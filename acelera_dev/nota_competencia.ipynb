# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
regr = LinearRegression()

# %% [markdown]
# ### Notas por competência
#     NU_NOTA_COMP1 -> Demonstrar domínio da modalidade escrita formal da Língua Portuguesa.
#     NU_NOTA_COMP2 -> Compreender a proposta de redação
#     NU_NOTA_COMP3 -> Selecionar, relacionar, organizar e interpretar informações, fatos, opiniões e argumentos em defesa de um ponto de vista
#     NU_NOTA_COMP4 -> Demonstrar conhecimento dos mecanismos linguísticos necessários para a construção da argumentação.
#     NU_NOTA_COMP5 - > Elaborar proposta de intervenção para o problema abordado, respeitando os direitos humanos.

# %%
df_train = pd.read_csv('train.csv')
df_train = df_train.dropna(0)
y = df_train.NU_NOTA_MT
x = df_train[['NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5']]

# %%
plt.figure()
plt.xlabel('NU_NOTA_COMP1')
plt.ylabel('Nota de matemática')
plt.title('Nota de matemática x NU_NOTA_COMP1')
plt.plot(x.NU_NOTA_COMP1, y)
plt.axis([0, 200, 0, 200])
plt.grid()
plt.show()

# %%
plt.scatter(x.NU_NOTA_COMP1, y)
plt.xlabel('NU_NOTA_COMP1')
plt.ylabel('Nota de Matemática')
plt.title('Relação matematica com ciências da natureza')
plt.show()

# %%
plt.scatter(x.NU_NOTA_COMP5, y)
plt.xlabel('NU_NOTA_COMP2')
plt.ylabel('Nota de Matemática')
plt.title('Relação matematica com ciências da natureza')
plt.show()

# %%
regr = LinearRegression()
regr.fit([x.NU_NOTA_COMP3], [y])
print(f'Coêficiente {regr.intercept_}')
print(f'n coeficiente {len(regr.coef_)}')
print(f'Mean SQUARE ERROR (MSE){np.mean((regr.predict(x)- y)**2)}')
# Out:
# Coêficiente [500.7 504.4 375.8 473.7 416.5 404.6 392.  430.9 357.1 490.3 390.5 368.6
#  422.9 577.1 475.9 551.  389.3 675.  413.5 488.6 416.6 389.  493.2 419.9
#  436.3 567.7 377.1 356.1 448.9 471.9 492.6 459.8 433.2 367.9 460.  482.7
#  573.  474.1 412.3 489.4 541.9 535.4 503.7 449.6 387.  385.9 397.5 403.4
#  384.2 386.3 353.1 394.3 456.1 719.5 432.3 467.2 404.1 386.  490.7 370.5
#  456.3 484.  531.6 379.7]
# n coeficiente 64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b74b5b521a8f> in <module>()
#       3 print(f'Coêficiente {regr.intercept_}')
#       4 print(f'n coeficiente {len(regr.coef_)}')
# ----> 5 print(f'Mean SQUARE ERROR (MSE){np.mean((regr.predict(x)- y)**2)}')
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# ...
